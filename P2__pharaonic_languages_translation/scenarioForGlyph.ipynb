# %%
"""
import os

def rename_images(folder_path):
    # Get the list of files in the folder
    files = os.listdir(folder_path)
    file_count = 0

    # Iterate over the files
    for file_name in files:
        # Check if the file is an image
        if file_name.lower().endswith(('.jpg', '.jpeg', '.png', '.gif')):
            # Create the new file name
            new_file_name = str(file_count) + os.path.splitext(file_name)[1]
            file_count += 1

            # Get the current file path and the new file path
            current_path = os.path.join(folder_path, file_name)
            new_path = os.path.join(folder_path, new_file_name)

            # Rename the file
            os.rename(current_path, new_path)
            print(f"Renamed {file_name} to {new_file_name}")

# Provide the folder path where the images are located
folder_path = 'C:\\Users\\hp\\Desktop\\yolov5\\runs'

# Call the function to rename the images
rename_images(folder_path)
"""
# Out:
# Renamed photo_1_2023-04-17_19-44-58_jpg.rf.79f0931dede73025490330d52186ed11.jpg to 0.jpg
# Renamed photo_1_2023-04-17_19-44-58_jpg.rf.c8d1873854cf91515263091004fa5c11.jpg to 1.jpg
# Renamed photo_1_2023-04-17_19-44-58_jpg.rf.f4c871daa5ae43bad448a599de61c016.jpg to 2.jpg
# Renamed photo_1_2023-04-17_19-45-06_jpg.rf.2b8d29a3017f79a7ef51213e8c5bae03.jpg to 3.jpg
# Renamed photo_1_2023-04-17_19-45-06_jpg.rf.4a664e1223907cd0317cdf5925be34e0.jpg to 4.jpg
# Renamed photo_1_2023-04-17_19-45-06_jpg.rf.54038959befd710a2870687f862fc94a.jpg to 5.jpg
# Renamed photo_1_2023-04-17_19-45-43_jpg.rf.4c9b1337e8a419b953b891e4ab2e0ec2.jpg to 6.jpg
# Renamed photo_1_2023-04-17_19-45-43_jpg.rf.b64029e4d5f92e7ead78dbe38ec1fef7.jpg to 7.jpg
# Renamed photo_1_2023-04-17_19-45-43_jpg.rf.e5bf01428aa2b3707b9f3a9f3bbeb358.jpg to 8.jpg
# Renamed photo_1_2023-04-17_19-45-54_jpg.rf.66baf19afa16d2115b51408be1ef8638.jpg to 9.jpg
# ...

# %%
# !pip install models
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py egg_info did not run successfully.
#   exit code: 1
#
#   [8 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\hp\AppData\Local\Temp\pip-install-hyahxjud\models_4e8b6a4fdc3e429782b42abd45607abc\setup.py", line 25, in <module>
#       import models
#     File "C:\Users\hp\AppData\Local\Temp\pip-install-hyahxjud\models_4e8b6a4fdc3e429782b42abd45607abc\models\__init__.py", line 23, in <module>
#       from base import *
#   ModuleNotFoundError: No module named 'base'
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# ...

# %%
# !pip install hamzaGlyph==0.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\hp\anaconda3\lib\site-packages)

# %%
# !pip install hamzaGlyph
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\hp\anaconda3\lib\site-packages)

# %%
# !pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Processing c:\users\hp\desktop\yolo\yolov5\hamzaglyph
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for hamzaGlyph: filename=hamzaGlyph-0.1-py3-none-any.whl size=1142 sha256=be8368ba504797d49dff95107428c0915da77f0a470a41e8672719b000067770
#   Stored in directory: C:\Users\hp\AppData\Local\Temp\pip-ephem-wheel-cache-3piht_pv\wheels\74\53\84\33bb5e0b754c72bfbc979a0fd8b852dfb848a364a7e9e7721b
# Successfully built hamzaGlyph
# ...
#   Attempting uninstall: hamzaGlyph
#     Found existing installation: hamzaGlyph 0.1
#     Uninstalling hamzaGlyph-0.1:
#       Successfully uninstalled hamzaGlyph-0.1
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\hp\anaconda3\lib\site-packages)

# %%
from hamzaGlyph.full import run_1,run_2

# %%
# !pip install hamzaGlyph==0.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# WARNING: Ignoring invalid distribution -cipy (c:\users\hp\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cipy (c:\users\hp\anaconda3\lib\site-packages)

# %%
# !pip list
# Out:
# WARNING: Ignoring invalid distribution -cipy (c:\users\hp\anaconda3\lib\site-packages)
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.3.0
# aiohttp                       3.8.3
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.11.0
# anaconda-navigator            2.3.2
# anaconda-project              0.11.1
# antlr4-python3-runtime        4.9.3
# anyio                         3.5.0
# appdirs                       1.4.4
# arabic-reshaper               2.1.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# asgiref                       3.6.0
# astor                         0.8.1
# astroid                       2.14.2
# astropy                       5.1
# astunparse                    1.6.3
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# ...

# %%
# !pip show hamzaGlyph
# Out:
# Name: hamzaGlyph
# Version: 0.1
# Summary: A Python library
# Home-page:
# Author: Mahmoud Hamza Mohammed Ibrahim Abdella
# Author-email: mahmoud.hamza1592001@gmail.com
# License:
# Location: c:\users\hp\anaconda3\lib\site-packages
# Requires:
# Required-by:
# WARNING: Ignoring invalid distribution -cipy (c:\users\hp\anaconda3\lib\site-packages)

# %%
# !pip uninstall scipy

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- --------------------
# absl-py                       1.3.0
# aiohttp                       3.8.3
# aiosignal                     1.2.0
# alabaster                     0.7.12
# anaconda-client               1.11.0
# anaconda-navigator            2.3.2
# anaconda-project              0.11.1
# antlr4-python3-runtime        4.9.3
# anyio                         3.5.0
# appdirs                       1.4.4
# arabic-reshaper               2.1.4
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# asgiref                       3.6.0
# astor                         0.8.1
# astroid                       2.14.2
# astropy                       5.1
# astunparse                    1.6.3
# async-timeout                 4.0.2
# atomicwrites                  1.4.0
# attrs                         22.1.0
# autocorrect                   2.6.1
# ...

# %%
conda info
# Out:
#      active environment : base
#     active env location : C:\Users\hp\anaconda3
#             shell level : 1
#        user config file : C:\Users\hp\.condarc
#  populated config files : C:\Users\hp\.condarc
#           conda version : 23.1.0
#     conda-build version : 3.22.0
#          python version : 3.9.13.final.0
#        virtual packages : __archspec=1=x86_64
#                           __cuda=12.0=0
#                           __win=0=0
#        base environment : C:\Users\hp\anaconda3  (writable)
#       conda av data dir : C:\Users\hp\anaconda3\etc\conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/win-64
#                           https://repo.anaconda.com/pkgs/main/noarch
#                           https://repo.anaconda.com/pkgs/r/win-64
#                           https://repo.anaconda.com/pkgs/r/noarch
#                           https://repo.anaconda.com/pkgs/msys2/win-64
# ...

# %%
conda activate base
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
conda remove -n base "-cipy"
# Out:
# Note: you may need to restart the kernel to use updated packages.
# CondaValueError: no package names supplied,
#        try "conda remove -h" for more details

# %%
import full as f

# %%
f.run_1
# Out:
# <function full.run_1(source, weights=WindowsPath('../yolov5/runs/train/exp3/weights/best.pt'), data=WindowsPath('../yolov5/data_1.yaml'), imgsz=(1024, 1024), conf_thres=0.5, iou_thres=0.45, max_det=1000, device='', view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=WindowsPath('../yolov5/runs/detect'), name='exp', exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1)>

# %%
from full import run_1,run_2
# Call the run_1() function
img = run_1(source="tstImg_5.jpg")
# Call the run_2() function
txt=run_2()
#return txt
print("The Name Of King is :",txt)
# Out:
# YOLOv5  v7.0-145-g94714fe Python-3.9.13 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients
# YOLOv5  v7.0-145-g94714fe Python-3.9.13 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients
# YOLOv5  v7.0-145-g94714fe Python-3.9.13 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1764577 parameters, 0 gradients
# The Name Of King is : unas

# %%
from hamzaGlyph.full import run_1,run_2
# Call the run_1() function
img = run_1(source="tstImg_5.jpg")
# Call the run_2() function
txt=run_2()
#return txt
print("The Name Of King is :",txt)
# Out:
# YOLOv5  v7.0-145-g94714fe Python-3.9.13 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients
# YOLOv5  v7.0-145-g94714fe Python-3.9.13 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients
# YOLOv5  v7.0-145-g94714fe Python-3.9.13 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1764577 parameters, 0 gradients
# The Name Of King is : unas

# %%
from hamzaGlyph.full import run_1,run_2

def translate(pic_path):
    # Call the run_1() function
    img = run_1(source=pic_path)
    # Call the run_2() function
    txt=run_2()
    return txt
    

print("the name of king : ",translate("tstImg_5.jpg"))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2324\2493438806.py in <module>
# ----> 1 from hamzaGlyph.full import run_1,run_2
#       2
#       3 def translate(pic_path):
#       4     # Call the run_1() function
#       5     img = run_1(source=pic_path)
#
# ~\Desktop\yolo\yolov5 in <module>
#      20 ROOT = Path(os.path.relpath(ROOT, Path.cwd()))  # relative
#      21
# ---> 22 from models.common import DetectMultiBackend
#      23 from utils.dataloaders import IMG_FORMATS, VID_FORMATS, LoadImages, LoadScreenshots, LoadStreams
#      24 from utils.general import (LOGGER, Profile, check_file, check_img_size, check_imshow, check_requirements, colorstr, cv2,
#
# ModuleNotFoundError: No module named 'models'

# %%
import cv2
from full_2 import run_1,run_2

def translate(pic_path):
    # Call the run_1() function
    img = run_1(source=pic_path)
    cv2.imshow("img",img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    # Call the run_2() function
    txt=run_2()
    return txt
    

print("the name of king : ",translate("exp3\\13.jpg"))
# Out:
# YOLOv5  v7.0-145-g94714fe Python-3.9.13 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8356\197223456.py in <module>
#      13
#      14
# ---> 15 print("the name of king : ",translate("exp3\\13.jpg"))
#
# ~\AppData\Local\Temp\ipykernel_8356\197223456.py in translate(pic_path)
#       4 def translate(pic_path):
#       5     # Call the run_1() function
# ----> 6     img = run_1(source=pic_path)
#       7     cv2.imshow("img",img)
#       8     cv2.waitKey(0)
#
# ~\anaconda3\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
# ...

# %%
import cv2
from full_2 import run_1,run_2

def translate(pic_path):
    # Call the run_1() function
    run_1(source=pic_path)
    #cv2.imshow("img",img)
    #cv2.waitKey(0)
    #cv2.destroyAllWindows()
    # Call the run_2() function
    txt=run_2(source_2="sec_roi.jpg")
    return txt
    

print("the name of king : ",translate("exp3\\13.jpg"))
# Out:
# YOLOv5  v7.0-145-g94714fe Python-3.9.13 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16100\1264678087.py in <module>
#      13
#      14
# ---> 15 print("the name of king : ",translate("exp3\\13.jpg"))
#
# ~\AppData\Local\Temp\ipykernel_16100\1264678087.py in translate(pic_path)
#       4 def translate(pic_path):
#       5     # Call the run_1() function
# ----> 6     run_1(source=pic_path)
#       7     #cv2.imshow("img",img)
#       8     #cv2.waitKey(0)
#
# ~\anaconda3\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
# ...

# %%
#290
#if source_2 is None:
        #source_2 =input("Enter path to source_2 image: ")

    #if source_2 is None:
     #   source_2 = run_1(source=ROOT / 'tstImg_5.jpg')
    #img_name = 'source_2.jpg'
    #cv2.imwrite(img_name, source_2)
    #source_2 = img_name

    #source_2 = str(source_2)

# %%
#257
#return roi

# %%
import cv2
from full_2 import run_1
from full_4 import run_2
from detectAfterCar2 import run

def translate(pic_path):
    # Call the run_1() function
    run_1(source=pic_path)
    img=cv2.imread("sec_roi.jpg")
    cv2.imshow("img",img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    # Call the run_2() function
    #txt=run_2()
    run(weights='runs/train/exp8/weights/best.pt' ,source= 'sec_roi.jpg',data= 'data_4.yaml')
    #return txt
    

#print("the name of king : ",translate("exp3\\13.jpg"))
translate("00033.jpg")#tstImg_5
# Out:
# YOLOv5  v7.0-145-g94714fe Python-3.9.13 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients
# YOLOv5  v7.0-145-g94714fe Python-3.9.13 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1786225 parameters, 0 gradients
# the name of king :  RmsssssHeliopolisRulerof

# %%
import cv2
from final import run_1,run_2
def translate(pic_path):
    # Call the run_1() function
    run_1(source=pic_path)
    img=cv2.imread("sec_roi.jpg")
    cv2.imshow("img",img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    # Call the run_2() function
    #txt=run_2()
    run_2(weights_2='runs/train/exp8/weights/best.pt' ,source_2= 'sec_roi.jpg',data= 'data_4.yaml')
    #return txt
    

#print("the name of king : ",translate("exp3\\13.jpg"))
translate("00033.jpg")#tstImg_5
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16100\12670356.py in <module>
#       1 import cv2
# ----> 2 from final import run_1,run_2
#       3 def translate(pic_path):
#       4     # Call the run_1() function
#       5     run_1(source=pic_path)
#
# ImportError: cannot import name 'run_2' from 'final' (C:\Users\hp\Desktop\yolo\yolov5\yolov5)

# %%
import cv2
import final 
run_2(source_2="00033.jpg")
img=cv2.imread("sec_roi.jpg")
cv2.imshow("img",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# YOLOv5  v7.0-145-g94714fe Python-3.9.13 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1786225 parameters, 0 gradients

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16100\3359676495.py in <module>
# ----> 1 from final import run_2
#
# ImportError: cannot import name 'run_2' from 'final' (C:\Users\hp\Desktop\yolo\yolov5\yolov5)

# %%
import cv2
from before import run_1
from after import run_2
#from full_4 import run_2
#from detectAfterCar2 import run

def translate(pic_path):
    # Call the run_1() function
    run_1(source=pic_path)
    #img=cv2.imread("sec_roi.jpg")
    #cv2.imshow("img",img)
    #cv2.waitKey(0)
    #cv2.destroyAllWindows()
    # Call the run_2() function
    txt=run_2()
    #run(weights='runs/train/exp8/weights/best.pt' ,source= 'sec_roi.jpg',data= 'data_4.yaml')
    return txt
    

print("the name of king : ",translate("tst_6.jpg"))
#translate("tst_6.jpg")#tstImg_5
# Out:
# YOLOv5  v7.0-145-g94714fe Python-3.9.13 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients
# Speed: 4.0ms pre-process, 293.6ms inference, 1.0ms NMS per image at shape (1, 3, 1024, 1024)
# Results saved to runs\detect\exp511
# YOLOv5  v7.0-145-g94714fe Python-3.9.13 torch-1.13.0+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1786225 parameters, 0 gradients
# the name of king :  wnnis
# the name of king :  wnnis

# %%
import cv2
from before import run_10
from after import run


def translate(pic_path):
    # Call the run_1() function
    #run_1(source=pic_path)
    
    # Call the run_2() function
    txt=run_2()
    
    #return txt
    


translate("00033.jpg")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3596\3020130726.py in <module>
#       1 import cv2
# ----> 2 from before import run_10
#       3 from after import run
#       4
#       5
#
# ImportError: cannot import name 'run_10' from 'before' (C:\Users\hp\Desktop\yolo\yolov5\yolov5)
